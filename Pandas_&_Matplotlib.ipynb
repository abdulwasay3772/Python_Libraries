# %% [markdown]
# ### **What's Pandas for?**

# %% [markdown]
# Pandas has so many uses that it might make sense to list the things it can't doinstead of what it can do.
# This tool is essentially your data’s home. Through pandas, you get acquaintedwith your data by cleaning, transforming, and analyzing it.
# **For example:** say you want to explore a dataset stored in a CSV on yourcomputer. Pandas will extract the data from that CSV into a DataFrame — atable, basically — then let you do things like:
#
# • Calculate statistics and answer questions about the data, like
#
# • What's the average, median, max, or min of each column?
#
# • Clean the data by doing things like removing missing values and filtering rowsor columns by some        criteria
#
# • Visualize the data with help from Matplotlib. Plot bars, lines, histograms,bubbles, and more.
#
# • Store the cleaned, transformed data back into a CSV, other file or database

# %% [markdown]
# ### **How to import Library?**

# %%
import pandas as pd #as pd means that i will use pd with dot operation to call the functions of this specfic library

# %% [markdown]
# ### **Now read a file**

# %%
data = pd.read_csv('/content/data for practice')

# %% [markdown]
# ### **Now display the read data**

# %%
data.head()
# Out:
#           Date/Time  ...  Water Heater:WaterSystems:Gas [kW](Hourly)
# 0   01/01  01:00:00  ...                                    6.350098
# 1   01/01  02:00:00  ...                                    0.020000
# 2   01/01  03:00:00  ...                                    0.592073
# 3   01/01  04:00:00  ...                                    0.020000
# 4   01/01  05:00:00  ...                                    0.592079
#
# [5 rows x 11 columns]

# %% [markdown]
# ### **No, I want to display the whole Dataset**

# %%
data
# Out:
#              Date/Time  ...  Water Heater:WaterSystems:Gas [kW](Hourly)
# 0      01/01  01:00:00  ...                                    6.350098
# 1      01/01  02:00:00  ...                                    0.020000
# 2      01/01  03:00:00  ...                                    0.592073
# 3      01/01  04:00:00  ...                                    0.020000
# 4      01/01  05:00:00  ...                                    0.592079
# ...                ...  ...                                         ...
# 8755   12/31  20:00:00  ...                                   13.334591
# 8756   12/31  21:00:00  ...                                   10.413044
# 8757   12/31  22:00:00  ...                                   12.755350
# 8758   12/31  23:00:00  ...                                   10.412404
# 8759   12/31  24:00:00  ...                                    5.192246
#
# [8760 rows x 11 columns]

# %% [markdown]
# ### **To find maximum Temprature in a given column**

# %%
data["Temp"].max() # Temp is the column name in dsataset
# Out:
# 3.9847084710000003

# %% [markdown]
# ### **How to find coressponding date for 26.3?**

# %%
coressponding_date_for_ = data.loc[data["Temp"] == 3.98470847132, "Date/Time"]
coressponding_date_for_
# Out:
# Series([], Name: Date/Time, dtype: object)

# %% [markdown]
# ### **Pandas offers count, mean, std, min, 25%, 50%, 75%, max etc**

# %% [markdown]
# ### **I’m interested in rows 20 till 25 and columns 1 to 2**

# %%
data.iloc[20: 26, 0: 2]
# Out:
#            Date/Time  Electricity:Facility [kW](Hourly)
# 20   01/01  21:00:00                          38.820425
# 21   01/01  22:00:00                          38.762936
# 22   01/01  23:00:00                          38.665754
# 23   01/01  24:00:00                          39.397812
# 24   01/02  01:00:00                          22.680207
# 25   01/02  02:00:00                          14.871327

# %% [markdown]
# ### **If you have used pd.head( ) and you want to know about the rows and cloumns**

# %%
data.shape
# Out:
# (8760, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Date/Time                                   8760 non-null   object
#  1   Electricity:Facility [kW](Hourly)           8760 non-null   float64
#  2   Temp                                        8760 non-null   float64
#  3   Cooling:Electricity [kW](Hourly)            8760 non-null   float64
#  4   Heating:Electricity [kW](Hourly)            8760 non-null   int64
#  5   InteriorLights:Electricity [kW](Hourly)     8760 non-null   float64
#  6   InteriorEquipment:Electricity [kW](Hourly)  8760 non-null   float64
#  7   Gas:Facility [kW](Hourly)                   8760 non-null   float64
#  8   Heating:Gas [kW](Hourly)                    8760 non-null   float64
# ...

# %% [markdown]
# ### **I want to display specifice number of columns**

# %%
pd.set_option('display.max_columns', 1)
pd.set_option('display.expand_frame_repr', True)

# %%
data1 = pd.read_csv('/content/data for practice')

# %%
data1
# Out:
#              Date/Time  ...
# 0      01/01  01:00:00  ...
# 1      01/01  02:00:00  ...
# 2      01/01  03:00:00  ...
# 3      01/01  04:00:00  ...
# 4      01/01  05:00:00  ...
# ...                ...  ...
# 8755   12/31  20:00:00  ...
# 8756   12/31  21:00:00  ...
# 8757   12/31  22:00:00  ...
# 8758   12/31  23:00:00  ...
# 8759   12/31  24:00:00  ...
#
# [8760 rows x 11 columns]

# %% [markdown]
# ### **By default head( ) function displays first 5 entries**

# %%
pd.set_option('display.max_columns',2)
data.head(10) #10 means to display first 10 entries
# Out:
#           Date/Time  ...  Water Heater:WaterSystems:Gas [kW](Hourly)
# 0   01/01  01:00:00  ...                                    6.350098
# 1   01/01  02:00:00  ...                                    0.020000
# 2   01/01  03:00:00  ...                                    0.592073
# 3   01/01  04:00:00  ...                                    0.020000
# 4   01/01  05:00:00  ...                                    0.592079
# 5   01/01  06:00:00  ...                                    0.020000
# 6   01/01  07:00:00  ...                                    4.037506
# 7   01/01  08:00:00  ...                                    4.037694
# 8   01/01  09:00:00  ...                                    4.612665
# 9   01/01  10:00:00  ...                                    4.038493
#
# [10 rows x 11 columns]

# %%
data.tail()
# Out:
#              Date/Time  ...  Water Heater:WaterSystems:Gas [kW](Hourly)
# 8755   12/31  20:00:00  ...                                   13.334591
# 8756   12/31  21:00:00  ...                                   10.413044
# 8757   12/31  22:00:00  ...                                   12.755350
# 8758   12/31  23:00:00  ...                                   10.412404
# 8759   12/31  24:00:00  ...                                    5.192246
#
# [5 rows x 11 columns]

# %%
data.tail(10)
# Out:
#              Date/Time  ...  Water Heater:WaterSystems:Gas [kW](Hourly)
# 8750   12/31  15:00:00  ...                                    7.508087
# 8751   12/31  16:00:00  ...                                    8.085316
# 8752   12/31  17:00:00  ...                                    8.084778
# 8753   12/31  18:00:00  ...                                   10.414787
# 8754   12/31  19:00:00  ...                                   12.754970
# 8755   12/31  20:00:00  ...                                   13.334591
# 8756   12/31  21:00:00  ...                                   10.413044
# 8757   12/31  22:00:00  ...                                   12.755350
# 8758   12/31  23:00:00  ...                                   10.412404
# 8759   12/31  24:00:00  ...                                    5.192246
#
# [10 rows x 11 columns]

# %% [markdown]
# ### **Now I want to access each column separately**

# %%
date = data['Date/Time']
d_50 = date.head(50)

# %%
Temp=data['Temp']
t_50=Temp.head(50)

# %% [markdown]
# ### **Now I want to plot this data (Fans:Electricity [kW](Hourly) with date) the date and time in  time series called index**

# %%
#first import matplotlib
import matplotlib.pyplot as plt # or from matplotlib import pyplot as plt

# %%
plt.plot(d_50,t_50,color='k',linestyle='--',marker='o',label='load')
plt.xlabel('date')
plt.ylabel('remprature')
plt.title('daily-minimum-load')
plt.legend()
plt.show()

# %% [markdown]
# ### **Another way to plot data set**

# %%
data.plot()

# %% [markdown]
# ### **Very Interesting to give a tabuler formate to data**

# %%
my_data = pd.DataFrame({"S.No":['1','2','3','4','5'],"Name":['Abdul','Wasay','Ahmad','Aslam','Tirmize'],"Gender":['Male','Male','Male','Male','Male']})

# %%
my_data
# Out:
#   S.No  ... Gender
# 0    1  ...   Male
# 1    2  ...   Male
# 2    3  ...   Male
# 3    4  ...   Male
# 4    5  ...   Male
#
# [5 rows x 3 columns]

# %% [markdown]
# ### **Now I want to export this data to a csv file**

# %% [markdown]
# Neither you can use filehandling approch like .write(my_data) because my_data is not a string it's dataframe nor we have a built-in function like int2str( ).......How to handle this lets focus on below code

# %%
dataframe = pd.DataFrame({"S.No":['1','2','3','4','5'],"Name":['Abdul','Wasay','Ahmad','Aslam','Tirmize'],"Gender":['Male','Male','Male','Male','Male']})

# %%
import os
#create csv file
my_file = open('from_dataframe_to_csv.csv','x') 
#export dataframe to csv file 
dataframe.to_csv('from_dataframe_to_csv.csv', index=False)
#read csv file
dataa = pd.read_csv('from_dataframe_to_csv.csv')
#display .csv file data
dataa
# Out:
#    S.No  ... Gender
# 0     1  ...   Male
# 1     2  ...   Male
# 2     3  ...   Male
# 3     4  ...   Male
# 4     5  ...   Male
#
# [5 rows x 3 columns]

# %% [markdown]
# ### **Lets plot another dataset**

# %%
import pandas as pd
import matplotlib. pyplot as plt
air_quality = pd. read_csv("/content/data2", index_col=0, parse_dates=True)
air_quality.head(6)
# Out:
#                   Electricity:Facility [kW](Hourly)  ...  \
# Date/Time                                            ...
#  01/01  01:00:00                          22.035977  ...
#  01/01  02:00:00                          14.649757  ...
#  01/01  03:00:00                          14.669567  ...
#  01/01  04:00:00                          14.677808  ...
#  01/01  05:00:00                          14.824794  ...
#  01/01  06:00:00                          22.182649  ...
#
#                   Water Heater:WaterSystems:Gas [kW](Hourly)
# Date/Time
#  01/01  01:00:00                                    9.246947
#  01/01  02:00:00                                    0.020000
#  01/01  03:00:00                                    0.020000
#  01/01  04:00:00                                    0.592052
#  01/01  05:00:00                                    0.020000
#  01/01  06:00:00                                    0.592057
#
# [6 rows x 10 columns]

# %% [markdown]
# ### **Line Plot**

# %%
air_quality. plot()

# %% [markdown]
# ### **Subplot**

# %%
axs = air_quality.plot.area(figsize=(16,8),subplots=True) #figsize=(L,W)
